# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/kaggle/input/bengaluru-house-price-data/Bengaluru_House_Data.csv")
data.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
data.shape
# Out:
# (13320, 9)

# %%
data.info
# Out:
# <bound method DataFrame.info of                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# ...

# %%
for column in data.columns:
    print(data[column].value_counts())
    print('*'*30)
# Out:
# area_type
# Super built-up  Area    8790
# Built-up  Area          2418
# Plot  Area              2025
# Carpet  Area              87
# Name: count, dtype: int64
# ******************************
# availability
# Ready To Move    10581
# 18-Dec             307
# 18-May             295
# 18-Apr             271
# 18-Aug             200
#                  ...
# 15-Aug               1
# 17-Jan               1
# 16-Nov               1
# 16-Jan               1
# 14-Jul               1
# Name: count, Length: 81, dtype: int64
# ******************************
# location
# Whitefield                        540
# Sarjapur  Road                    399
# Electronic City                   302
# Kanakpura Road                    273
# Thanisandra                       234
#                                  ...
# Bapuji Layout                       1
# 1st Stage Radha Krishna Layout      1
# BEML Layout 5th stage               1
# singapura paradise                  1
# ...

# %%
data.groupby('area_type')['area_type'].agg('count')
# Out:
# area_type
# Built-up  Area          2418
# Carpet  Area              87
# Plot  Area              2025
# Super built-up  Area    8790
# Name: area_type, dtype: int64

# %%
data = data.drop(['area_type', 'society', 'balcony', 'availability'], axis='columns')

# %%
data.head()
# Out:
#                    location       size total_sqft  bath   price
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00
# 2               Uttarahalli      3 BHK       1440   2.0   62.00
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00
# 4                  Kothanur      2 BHK       1200   2.0   51.00

# %%
data.isnull().sum()
# Out:
# location       1
# size          16
# total_sqft     0
# bath          73
# price          0
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum()
# Out:
# location      0
# size          0
# total_sqft    0
# bath          0
# price         0
# dtype: int64

# %%
data['size'].unique()
# Out:
# array(['2 BHK', '4 Bedroom', '3 BHK', '4 BHK', '6 Bedroom', '3 Bedroom',
#        '1 BHK', '1 RK', '1 Bedroom', '8 Bedroom', '2 Bedroom',
#        '7 Bedroom', '5 BHK', '7 BHK', '6 BHK', '5 Bedroom', '11 BHK',
#        '9 BHK', '9 Bedroom', '27 BHK', '10 Bedroom', '11 Bedroom',
#        '10 BHK', '19 BHK', '16 BHK', '43 Bedroom', '14 BHK', '8 BHK',
#        '12 Bedroom', '13 BHK', '18 Bedroom'], dtype=object)

# %%
data['bhk'] = data['size'].apply(lambda x: int(x.split(' ')[0]))

# %%
data.head()
# Out:
#                    location       size total_sqft  bath   price  bhk
# 0  Electronic City Phase II      2 BHK       1056   2.0   39.07    2
# 1          Chikka Tirupathi  4 Bedroom       2600   5.0  120.00    4
# 2               Uttarahalli      3 BHK       1440   2.0   62.00    3
# 3        Lingadheeranahalli      3 BHK       1521   3.0   95.00    3
# 4                  Kothanur      2 BHK       1200   2.0   51.00    2

# %%
data = data.drop(['size'], axis='columns')

# %%
data.head()
# Out:
#                    location total_sqft  bath   price  bhk
# 0  Electronic City Phase II       1056   2.0   39.07    2
# 1          Chikka Tirupathi       2600   5.0  120.00    4
# 2               Uttarahalli       1440   2.0   62.00    3
# 3        Lingadheeranahalli       1521   3.0   95.00    3
# 4                  Kothanur       1200   2.0   51.00    2

# %%
data['bhk'].max()
# Out:
# 43

# %%
data[data.bhk > 20]
# Out:
#                        location total_sqft  bath  price  bhk
# 1718  2Electronic City Phase II       8000  27.0  230.0   27
# 4684                Munnekollal       2400  40.0  660.0   43

# %%
data['total_sqft'].unique()
# Out:
# array(['1056', '2600', '1440', ..., '1133 - 1384', '774', '4689'],
#       dtype=object)

# %%
def is_float(x):
    try:
        float(x)
    except:
        return False
    return True

# %%
data[~data['total_sqft'].apply(is_float)].head(10)
# Out:
#                location      total_sqft  bath    price  bhk
# 30            Yelahanka     2100 - 2850   4.0  186.000    4
# 122              Hebbal     3067 - 8156   4.0  477.000    4
# 137  8th Phase JP Nagar     1042 - 1105   2.0   54.005    2
# 165            Sarjapur     1145 - 1340   2.0   43.490    2
# 188            KR Puram     1015 - 1540   2.0   56.800    2
# 410             Kengeri  34.46Sq. Meter   1.0   18.500    1
# 549         Hennur Road     1195 - 1440   2.0   63.770    2
# 648             Arekere       4125Perch   9.0  265.000    9
# 661           Yelahanka     1120 - 1145   2.0   48.130    2
# 672        Bettahalsoor     3090 - 5002   4.0  445.000    4

# %%
def sqftRange_to_num(x):
    tokens = x.split('-')
    if(len(tokens) == 2):
        return (float(tokens[0]) + float(tokens[1]))/2
    try:
        return float(x)
    except:
        return None

# %%
sqftRange_to_num('1500 - 1700')
# Out:
# 1600.0

# %%
sqftRange_to_num('34.46Sq. Meter')

# %%
data['total_sqft'] = data['total_sqft'].apply(sqftRange_to_num)

# %%
data.head(10)
# Out:
#                    location  total_sqft  bath   price  bhk
# 0  Electronic City Phase II      1056.0   2.0   39.07    2
# 1          Chikka Tirupathi      2600.0   5.0  120.00    4
# 2               Uttarahalli      1440.0   2.0   62.00    3
# 3        Lingadheeranahalli      1521.0   3.0   95.00    3
# 4                  Kothanur      1200.0   2.0   51.00    2
# 5                Whitefield      1170.0   2.0   38.00    2
# 6          Old Airport Road      2732.0   4.0  204.00    4
# 7              Rajaji Nagar      3300.0   4.0  600.00    4
# 8              Marathahalli      1310.0   3.0   63.25    3
# 9              Gandhi Bazar      1020.0   6.0  370.00    6

# %% [markdown]
# ## Feature Engineering

# %%
data['price_per_sqft'] = data['price']*100000/data['total_sqft']
data.head()
# Out:
#                    location  total_sqft  bath   price  bhk  price_per_sqft
# 0  Electronic City Phase II      1056.0   2.0   39.07    2     3699.810606
# 1          Chikka Tirupathi      2600.0   5.0  120.00    4     4615.384615
# 2               Uttarahalli      1440.0   2.0   62.00    3     4305.555556
# 3        Lingadheeranahalli      1521.0   3.0   95.00    3     6245.890861
# 4                  Kothanur      1200.0   2.0   51.00    2     4250.000000

# %%
len(data['location'].unique())
# Out:
# 1304

# %%
data['location'] = data['location'].apply(lambda x: x.strip())

location_freq = data.groupby('location')['location'].agg('count').sort_values(ascending = False)
location_freq
# Out:
# location
# Whitefield               535
# Sarjapur  Road           392
# Electronic City          304
# Kanakpura Road           266
# Thanisandra              236
#                         ...
# 1 Giri Nagar               1
# Kanakapura Road,           1
# Kanakapura main  Road      1
# Karnataka Shabarimala      1
# whitefiled                 1
# Name: location, Length: 1293, dtype: int64

# %%
len(location_freq[location_freq <= 10])
# Out:
# 1052

# %%
less_freq_loc = location_freq[location_freq <= 10]
less_freq_loc
# Out:
# location
# Basapura                 10
# 1st Block Koramangala    10
# Gunjur Palya             10
# Kalkere                  10
# Sector 1 HSR Layout      10
#                          ..
# 1 Giri Nagar              1
# Kanakapura Road,          1
# Kanakapura main  Road     1
# Karnataka Shabarimala     1
# whitefiled                1
# Name: location, Length: 1052, dtype: int64

# %%
data['location'] = data['location'].apply(lambda x: 'other' if x in less_freq_loc else x)

# %%
len(data['location'].unique())
# Out:
# 242

# %%
data[data['total_sqft']/data['bhk'] < 300].head()  #Outliers
# Out:
#                location  total_sqft  bath  price  bhk  price_per_sqft
# 9                 other      1020.0   6.0  370.0    6    36274.509804
# 45           HSR Layout       600.0   9.0  200.0    8    33333.333333
# 58        Murugeshpalya      1407.0   4.0  150.0    6    10660.980810
# 68  Devarachikkanahalli      1350.0   7.0   85.0    8     6296.296296
# 70                other       500.0   3.0  100.0    3    20000.000000

# %%
data.shape
# Out:
# (13246, 6)

# %%
data = data[~(data['total_sqft']/data['bhk'] < 300)]
data.shape
# Out:
# (12502, 6)

# %%
data['price_per_sqft'].describe()
# Out:
# count     12456.000000
# mean       6308.502826
# std        4168.127339
# min         267.829813
# 25%        4210.526316
# 50%        5294.117647
# 75%        6916.666667
# max      176470.588235
# Name: price_per_sqft, dtype: float64

# %%
def remove_pps_outliers(df):
    df_out = pd.DataFrame()
    for key, subdf in df.groupby('location'):
        m = np.mean(subdf.price_per_sqft)
        st = np.std(subdf.price_per_sqft)
        reduced_df = subdf[(subdf.price_per_sqft>(m-st)) & (subdf.price_per_sqft<=(m+st))]
        df_out = pd.concat([df_out, reduced_df], ignore_index = True)
    return df_out

# %%
data = remove_pps_outliers(data)

# %%
data.shape
# Out:
# (10241, 6)

# %%
def plot_scatter_chart(df, location):
    bhk2 = data[(data.location == location) & (data.bhk == 2)]
    bhk3 = data[(data.location == location) & (data.bhk == 3)]
    matplotlib.rcParams['figure.figsize'] = (15, 10)
    plt.scatter(bhk2.total_sqft, bhk2.price_per_sqft, color='blue', label='2 bhk', s=50)
    plt.scatter(bhk3.total_sqft, bhk3.price_per_sqft, marker='*', color='green', label='3 bhk', s=50)
    plt.xlabel("Total sqft area")
    plt.ylabel("Price Per Square Feet")
    plt.title(location)
    plt.legend()
    
plot_scatter_chart(data, "Rajaji Nagar")

# %%
plot_scatter_chart(data, "Hebbal")

# %% [markdown]
# We will remove properties where for same location,(for eg.) the price of 3 bedroom apartment is less than 2 bedroom apartment(which have same sqft area). <br/>
#
# We will build a dictionary like this, <br/>
# { <br/>
#     '1':{ <br/>
#          'mean': 4000, <br/>
#          'std': 2000,  <br/>
#          'count': 34   <br/>
#     },    <br/>
#     '2':{ <br/>
#          'mean': 4300, <br/>
#          'std': 2300,  <br/>
#          'count': 22   <br/>
#     }     <br/>
# } <br/>
#
# Similarly we will do for 2 bhk apartment whose price_per_sqft is less than mean of price_per_sqft of 1 bhk apartment.

# %%
def remove_bhk_outliers(df):
    exclude_indices = np.array([])
    for location, location_df in df.groupby('location'):
        bhk_stats = {}
        for bhk, bhk_df in location_df.groupby('bhk'):
            bhk_stats[bhk] = {
                'mean': np.mean(bhk_df.price_per_sqft),
                'std': np.std(bhk_df.price_per_sqft),
                'count': bhk_df.shape[0]
            }
        for bhk, bhk_df in location_df.groupby('bhk'):
            stats = bhk_stats.get(bhk - 1)
            if stats and stats['count'] > 5:
                exclude_indices = np.append(exclude_indices, bhk_df[bhk_df.price_per_sqft < (stats['mean'])].index.values)
    return df.drop(exclude_indices, axis = 'index')

# %%
data = remove_bhk_outliers(data)

# %%
data.shape
# Out:
# (7329, 6)

# %%
plot_scatter_chart(data, "Hebbal")

# %%
matplotlib.rcParams['figure.figsize'] = (20, 10)
plt.hist(data.price_per_sqft, rwidth = 0.8)
plt.xlabel("Price Per Square Feet")
plt.ylabel("Count")
# Out:
# Text(0, 0.5, 'Count')

# %%
data['bath'].unique()
# Out:
# array([ 4.,  3.,  2.,  5.,  8.,  1.,  6.,  7.,  9., 12., 16., 13.])

# %%
data[data.bath > 10]
# Out:
#             location  total_sqft  bath  price  bhk  price_per_sqft
# 5277  Neeladri Nagar      4000.0  12.0  160.0   10     4000.000000
# 8486           other     12000.0  12.0  525.0   10     4375.000000
# 8575           other     10000.0  16.0  550.0   16     5500.000000
# 9308           other      6000.0  12.0  150.0   11     2500.000000
# 9639           other      5425.0  13.0  275.0   13     5069.124424

# %%
data[data.bath > data.bhk+2]
# Out:
#            location  total_sqft  bath   price  bhk  price_per_sqft
# 1626  Chikkabanavar      2460.0   7.0    80.0    4     3252.032520
# 5238     Nagasandra      7000.0   8.0   450.0    4     6428.571429
# 6711    Thanisandra      1806.0   6.0   116.0    3     6423.034330
# 8411          other     11338.0   9.0  1000.0    6     8819.897689

# %%
data = data[data.bath < data.bhk + 2]

# %%
data.shape
# Out:
# (7251, 6)

# %%
clean_data = data.drop(['price_per_sqft'], axis = 'columns')

# %%
clean_data.head(10)
# Out:
#                location  total_sqft  bath  price  bhk
# 0   1st Block Jayanagar      2850.0   4.0  428.0    4
# 1   1st Block Jayanagar      1630.0   3.0  194.0    3
# 2   1st Block Jayanagar      1875.0   2.0  235.0    3
# 3   1st Block Jayanagar      1200.0   2.0  130.0    3
# 4   1st Block Jayanagar      1235.0   2.0  148.0    2
# 5   1st Block Jayanagar      2750.0   4.0  413.0    4
# 6   1st Block Jayanagar      2450.0   4.0  368.0    4
# 8    1st Phase JP Nagar      1875.0   3.0  167.0    3
# 9    1st Phase JP Nagar      1500.0   5.0   85.0    5
# 10   1st Phase JP Nagar      2065.0   4.0  210.0    3

# %%
dummies = pd.get_dummies(clean_data.location)
dummies.head()
# Out:
#    1st Block Jayanagar  1st Phase JP Nagar  2nd Phase Judicial Layout  \
# 0                 True               False                      False
# 1                 True               False                      False
# 2                 True               False                      False
# 3                 True               False                      False
# 4                 True               False                      False
#
#    2nd Stage Nagarbhavi  5th Block Hbr Layout  5th Phase JP Nagar  \
# 0                 False                 False               False
# 1                 False                 False               False
# 2                 False                 False               False
# 3                 False                 False               False
# 4                 False                 False               False
#
#    6th Phase JP Nagar  7th Phase JP Nagar  8th Phase JP Nagar  \
# 0               False               False               False
# ...

# %%
mod_data = pd.concat([clean_data, dummies.drop('other', axis='columns')], axis='columns')

# %%
mod_data.head()
# Out:
#               location  total_sqft  bath  price  bhk  1st Block Jayanagar  \
# 0  1st Block Jayanagar      2850.0   4.0  428.0    4                 True
# 1  1st Block Jayanagar      1630.0   3.0  194.0    3                 True
# 2  1st Block Jayanagar      1875.0   2.0  235.0    3                 True
# 3  1st Block Jayanagar      1200.0   2.0  130.0    3                 True
# 4  1st Block Jayanagar      1235.0   2.0  148.0    2                 True
#
#    1st Phase JP Nagar  2nd Phase Judicial Layout  2nd Stage Nagarbhavi  \
# 0               False                      False                 False
# 1               False                      False                 False
# 2               False                      False                 False
# 3               False                      False                 False
# 4               False                      False                 False
#
#    5th Block Hbr Layout  ...  Vijayanagar  Vishveshwarya Layout  \
# ...

# %%
mod_data = mod_data.drop('location', axis='columns')

# %%
mod_data.head()
# Out:
#    total_sqft  bath  price  bhk  1st Block Jayanagar  1st Phase JP Nagar  \
# 0      2850.0   4.0  428.0    4                 True               False
# 1      1630.0   3.0  194.0    3                 True               False
# 2      1875.0   2.0  235.0    3                 True               False
# 3      1200.0   2.0  130.0    3                 True               False
# 4      1235.0   2.0  148.0    2                 True               False
#
#    2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# 0                      False                 False                 False
# 1                      False                 False                 False
# 2                      False                 False                 False
# 3                      False                 False                 False
# 4                      False                 False                 False
#
#    5th Phase JP Nagar  ...  Vijayanagar  Vishveshwarya Layout  \
# ...

# %%
mod_data.shape
# Out:
# (7251, 245)

# %%
X = mod_data.drop('price', axis='columns')

# %%
X.head()
# Out:
#    total_sqft  bath  bhk  1st Block Jayanagar  1st Phase JP Nagar  \
# 0      2850.0   4.0    4                 True               False
# 1      1630.0   3.0    3                 True               False
# 2      1875.0   2.0    3                 True               False
# 3      1200.0   2.0    3                 True               False
# 4      1235.0   2.0    2                 True               False
#
#    2nd Phase Judicial Layout  2nd Stage Nagarbhavi  5th Block Hbr Layout  \
# 0                      False                 False                 False
# 1                      False                 False                 False
# 2                      False                 False                 False
# 3                      False                 False                 False
# 4                      False                 False                 False
#
#    5th Phase JP Nagar  6th Phase JP Nagar  ...  Vijayanagar  \
# 0               False               False  ...        False
# ...

# %%
Y = mod_data.price
Y.head()
# Out:
# 0    428.0
# 1    194.0
# 2    235.0
# 3    130.0
# 4    148.0
# Name: price, dtype: float64

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=10)

# %%
from sklearn.linear_model import LinearRegression

lr_clf = LinearRegression()
lr_clf.fit(X_train, Y_train)
lr_clf.score(X_test, Y_test)
# Out:
# 0.8452277697874291

# %% [markdown]
# Further Cross Validation

# %%
from sklearn.model_selection import ShuffleSplit
from sklearn.model_selection import cross_val_score

cross_v = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)

cross_val_score(LinearRegression(), X, Y, cv = cross_v)
# Out:
# array([0.82430186, 0.77166234, 0.85089567, 0.80837764, 0.83653286])

# %%
def predict_price(location, sqft, bath, bhk):
    loc_index = np.where(X.columns == location)[0][0]
    
    x = np.zeros(len(X.columns))
    x[0] = sqft
    x[1] = bath
    x[2] = bhk
    
    if loc_index >= 0:
        x[loc_index] = 1
    
    return lr_clf.predict([x])[0]

# %%
predict_price('1st Phase JP Nagar', 1000, 2, 2)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 83.49904677170528

# %%
predict_price('1st Phase JP Nagar', 1000, 2, 3)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 81.72616900745913

# %%
predict_price('Indira Nagar', 1000, 2, 2)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 181.27815484007007

# %%
predict_price('Indira Nagar', 1000, 3, 3)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 184.5843020203357

# %%
import pickle
with open('linear_re_estate_predict_model.pkl', 'wb') as f:
    pickle.dump(lr_clf, f)

# %%
import json
columns = {
    'data_columns': [col.lower() for col in X.columns]
}
with open("columns.json", "w") as f:
    f.write(json.dumps(columns))
